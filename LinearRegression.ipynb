# %%
# Replace with your GitHub repo and token
repo_url = "https://github.com/Programo-Sapiens/dataSciencebyDigvijay.git"
token = "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"  # Store securely

# Configure Git
# !git config --global user.email "digvijaylucky251@gmail.com"
# !git config --global user.name "Programo-Sapiens"

# Clone your repo
# !git clone https://{token}@github.com/Programo-Sapiens/dataSciencebyDigvijay.git
# %cd dataSciencebyDigvijay
# Out:
# Cloning into 'dataSciencebyDigvijay'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/dataSciencebyDigvijay/dataSciencebyDigvijay

# %% [markdown]
# CODE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/"
# Out:
# EDA.ipynb		Matrix.ipynb	      Untitled0.ipynb
# Gilbert_S_ex-2.1.ipynb	Office_Panda.ipynb    Untitled2.ipynb
# kaggle			Panda_digvijay.ipynb  updated_notebook.ipynb
# LinearRegression.ipynb	state_crime.csv

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/LinearRegression.ipynb" /content/dataSciencebyDigvijay/

# %%
import pandas as pd
import numpy as np

# %%
print('digvijay')

a=2+3
print(a*2)
# Out:
# digvijay
# 10

# %%
# !ls
# Out:
# README.md

# %%
# !git add LinearRegression.ipynb
# !git commit -m "3nd time commenting to test from colab"
# !git push origin main
# Out:
# fatal: pathspec 'LinearRegression.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
